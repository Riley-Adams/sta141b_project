# %% [markdown]
# # Data Collection:
#
# # Webscraping basic RateMyProfessors (RMP) info for all professors at UC Davis

# %%
# import modules
import pandas as pd
import requests
import requests_cache
import json
import time
from tqdm import tqdm, trange

# %%
# set up cache
requests_cache.install_cache("profs")

# %% [markdown]
# ## Request data from RMP

# %%
# endpoint and header for POST request
url = 'https://www.ratemyprofessors.com/graphql'
headers = {
    "Authorization": "Basic dGVzdDp0ZXN0", 
}

# %% [markdown]
# ### Initial request (first 8 professors)

# %%
# data provided for GraphQL
data = {
    "query":"query TeacherSearchPaginationQuery(\n  $count: Int!\n  $cursor: String\n  $query: TeacherSearchQuery!\n) {\n  search: newSearch {\n    ...TeacherSearchPagination_search_1jWD3d\n  }\n}\n\nfragment TeacherSearchPagination_search_1jWD3d on newSearch {\n  teachers(query: $query, first: $count, after: $cursor) {\n    didFallback\n    edges {\n      cursor\n      node {\n        ...TeacherCard_teacher\n        id\n        __typename\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    resultCount\n    filters {\n      field\n      options {\n        value\n        id\n      }\n    }\n  }\n}\n\nfragment TeacherCard_teacher on Teacher {\n  id\n  legacyId\n  avgRating\n  numRatings\n  ...CardFeedback_teacher\n  ...CardSchool_teacher\n  ...CardName_teacher\n  ...TeacherBookmark_teacher\n}\n\nfragment CardFeedback_teacher on Teacher {\n  wouldTakeAgainPercent\n  avgDifficulty\n}\n\nfragment CardSchool_teacher on Teacher {\n  department\n  school {\n    name\n    id\n  }\n}\n\nfragment CardName_teacher on Teacher {\n  firstName\n  lastName\n}\n\nfragment TeacherBookmark_teacher on Teacher {\n  id\n  isSaved\n}\n",
    "variables":{
        "count":10000, # number of professors
        #"cursor":cursor,
        "query":{
            "text":"",
            "schoolID":"U2Nob29sLTEwNzM=",
            "fallback":True,
            "departmentID":None
        }
    }
}

# %%
# response/check status
response = requests.post(url, headers = headers, json=data)
response.raise_for_status()

# %%
# put response into dataframe
cursorDF = pd.DataFrame(response.json()['data']['search']['teachers']['edges'])
cursorDF
# Out:
#                             cursor  \
# 0         YXJyYXljb25uZWN0aW9uOjA=
# 1         YXJyYXljb25uZWN0aW9uOjE=
# 2         YXJyYXljb25uZWN0aW9uOjI=
# 3         YXJyYXljb25uZWN0aW9uOjM=
# 4         YXJyYXljb25uZWN0aW9uOjQ=
# ...                            ...
# 4466  YXJyYXljb25uZWN0aW9uOjQ0NjY=
# 4467  YXJyYXljb25uZWN0aW9uOjQ0Njc=
# 4468  YXJyYXljb25uZWN0aW9uOjQ0Njg=
# 4469  YXJyYXljb25uZWN0aW9uOjQ0Njk=
# 4470  YXJyYXljb25uZWN0aW9uOjQ0NzA=
#
#                                                    node
# 0     {'__typename': 'Teacher', 'avgDifficulty': 2.9...
# 1     {'__typename': 'Teacher', 'avgDifficulty': 2.7...
# 2     {'__typename': 'Teacher', 'avgDifficulty': 3.1...
# 3     {'__typename': 'Teacher', 'avgDifficulty': 2.5...
# 4     {'__typename': 'Teacher', 'avgDifficulty': 3.6...
# ...                                                 ...
# 4466  {'__typename': 'Teacher', 'avgDifficulty': 4.3...
# 4467  {'__typename': 'Teacher', 'avgDifficulty': 4.7...
# 4468  {'__typename': 'Teacher', 'avgDifficulty': 3.7...
# 4469  {'__typename': 'Teacher', 'avgDifficulty': 4, ...
# 4470  {'__typename': 'Teacher', 'avgDifficulty': 4.1...
#
# [4471 rows x 2 columns]

# %%
# initialize dataframe
profs = pd.DataFrame(columns=cursorDF['node'][0].keys())
profs
# Out:
# Empty DataFrame
# Columns: [__typename, avgDifficulty, avgRating, department, firstName, id, isSaved, lastName, legacyId, numRatings, school, wouldTakeAgainPercent]
# Index: []

# %%
# loop to populate profs df
for i in trange(0, len(cursorDF)):
    
    # temporary dictionary
    tempDict = cursorDF['node'][i]
    
    # delete problematic/unnecessary dictionary within dictionary
    del tempDict['school']

    # convert dict to temporary dataframe
    tempDF = pd.DataFrame(tempDict, index=[i])

    # append tempDF to profs df
    profs.loc[len(profs)] = tempDF.iloc[0,:]
# Out:
#   0%|          | 0/4471 [00:00<?, ?it/s]C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
#   1%|          | 48/4471 [00:00<00:09, 475.36it/s]C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
#   2%|▏         | 97/4471 [00:00<00:09, 476.56it/s]C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
#   3%|▎         | 147/4471 [00:00<00:09, 477.60it/s]C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
# ...
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
#  99%|█████████▉| 4447/4471 [00:12<00:00, 346.71it/s]C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_13864\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# 100%|██████████| 4471/4471 [00:12<00:00, 361.48it/s]

# %%
# view profs df
profs
# Out:
#      __typename avgDifficulty avgRating        department firstName  \
# 0       Teacher           2.9       3.3         Languages    Robert
# 1       Teacher           2.7       2.6      Anthropology      Aram
# 2       Teacher           3.1       3.2    Social Science   Patrick
# 3       Teacher           2.5       4.5      Anthropology     Henry
# 4       Teacher           3.6       3.8      Anthropology     Peter
# ...         ...           ...       ...               ...       ...
# 4466    Teacher           4.3       2.3  Computer Science     Chris
# 4467    Teacher           4.7         2  Computer Science     Daryl
# 4468    Teacher           3.7       1.6           Science    Daniel
# 4469    Teacher             4       3.7           Biology   Kenneth
# 4470    Teacher           4.1       3.8           Physics     Yifan
#
#                         id isSaved       lastName legacyId numRatings  school  \
# 0         VGVhY2hlci05NTY2   False         Borgen     9566         39     NaN
# 1         VGVhY2hlci05NTY4   False       Yengoyan     9568         47     NaN
# 2         VGVhY2hlci05NTcw   False  Carroll-Burke     9570         13     NaN
# 3     VGVhY2hlci0xMzQ4MQ==   False        McHenry    13481        124     NaN
# 4     VGVhY2hlci0yMjIzMA==   False         Rodman    22230         73     NaN
# ...                    ...     ...            ...      ...        ...     ...
# 4466  VGVhY2hlci00NjU5MTM=   False          Nitta   465913        189     NaN
# 4467  VGVhY2hlci0yNTA5NTcy   False        Posnett  2509572         57     NaN
# 4468  VGVhY2hlci0xMjUyNjg=   False         Ferenc   125268         29     NaN
# 4469  VGVhY2hlci0xNTE4OTQ=   False           Hilt   151894        325     NaN
# 4470  VGVhY2hlci0yNzgxMTI1   False           Tang  2781125         18     NaN
#
#      wouldTakeAgainPercent
# 0                       -1
# 1                       -1
# 2                       -1
# 3                       -1
# 4                       -1
# ...                    ...
# 4466               21.3115
# 4467                27.451
# 4468                9.0909
# 4469               56.1798
# 4470                   100
#
# [4471 rows x 12 columns]

# %%
# tidy columns
profs = profs[['__typename', 'firstName', 'lastName', 'department', 'id', 'legacyId', 'numRatings', 'avgRating', 'avgDifficulty']]
profs
# Out:
#      __typename firstName       lastName        department  \
# 0       Teacher    Robert         Borgen         Languages
# 1       Teacher      Aram       Yengoyan      Anthropology
# 2       Teacher   Patrick  Carroll-Burke    Social Science
# 3       Teacher     Henry        McHenry      Anthropology
# 4       Teacher     Peter         Rodman      Anthropology
# ...         ...       ...            ...               ...
# 4466    Teacher     Chris          Nitta  Computer Science
# 4467    Teacher     Daryl        Posnett  Computer Science
# 4468    Teacher    Daniel         Ferenc           Science
# 4469    Teacher   Kenneth           Hilt           Biology
# 4470    Teacher     Yifan           Tang           Physics
#
#                         id legacyId numRatings avgRating avgDifficulty
# 0         VGVhY2hlci05NTY2     9566         39       3.3           2.9
# 1         VGVhY2hlci05NTY4     9568         47       2.6           2.7
# 2         VGVhY2hlci05NTcw     9570         13       3.2           3.1
# 3     VGVhY2hlci0xMzQ4MQ==    13481        124       4.5           2.5
# 4     VGVhY2hlci0yMjIzMA==    22230         73       3.8           3.6
# ...                    ...      ...        ...       ...           ...
# 4466  VGVhY2hlci00NjU5MTM=   465913        189       2.3           4.3
# 4467  VGVhY2hlci0yNTA5NTcy  2509572         57         2           4.7
# 4468  VGVhY2hlci0xMjUyNjg=   125268         29       1.6           3.7
# 4469  VGVhY2hlci0xNTE4OTQ=   151894        325       3.7             4
# 4470  VGVhY2hlci0yNzgxMTI1  2781125         18       3.8           4.1
#
# [4471 rows x 9 columns]

# %%
# these should be removed. professors with no ratings
profs[profs['avgRating'] < 1]
# Out:
#      __typename   firstName            lastName                  department  \
# 141     Teacher        Paul             Baumann                     Biology
# 199     Teacher          Te            Williams                 Agriculture
# 224     Teacher       Scott  Schonfeldt-Aultman              Ethnic Studies
# 237     Teacher       Craig            McDonald                    Medicine
# 255     Teacher    Sharlene              Gilman                     English
# ...         ...         ...                 ...                         ...
# 4385    Teacher      George             Hegarty  University Writing Program
# 4386    Teacher   Sen-Ching              Cheung            Computer Science
# 4396    Teacher  Alessandro              Ossola       Environmental Science
# 4410    Teacher      Graham            McDougal                         Art
# 4411    Teacher     Alexios      Panoutsopoulos         Biological Sciences
#
#                         id legacyId numRatings avgRating avgDifficulty
# 141   VGVhY2hlci0xNTkyODg=   159288          0         0             0
# 199   VGVhY2hlci0yMTQ2NzI=   214672          0         0             0
# 224   VGVhY2hlci0yMjg4NDQ=   228844          0         0             0
# 237   VGVhY2hlci0yNDczNDU=   247345          0         0             0
# 255   VGVhY2hlci0yNTg2ODc=   258687          0         0             0
# ...                    ...      ...        ...       ...           ...
# 4385  VGVhY2hlci0yODQxMzM3  2841337          0         0             0
# 4386  VGVhY2hlci0yODQxNDIw  2841420          0         0             0
# 4396  VGVhY2hlci0yODQ0MDk3  2844097          0         0             0
# 4410  VGVhY2hlci0yNjc2MzU4  2676358          0         0             0
# 4411  VGVhY2hlci0yODA1MzIz  2805323          0         0             0
#
# [534 rows x 9 columns]

# %%
# drop rows with 0 ratings
idxRemove = profs[profs['avgRating'] < 1].index
profs = profs.drop(idxRemove)

# %%
# save profs df to csv
profs.to_csv("profs.csv")
