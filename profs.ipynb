# %% [markdown]
# # Data Collection:
#
# # Webscraping basic RateMyProfessors (RMP) info for all professors at UC Davis

# %%
# import modules
import pandas as pd
import requests
import requests_cache
import json
import time
from tqdm import tqdm, trange

# %%
# set up cache
requests_cache.install_cache("profs")

# %% [markdown]
# ## Request data from RMP

# %%
# endpoint and header for POST request
url = 'https://www.ratemyprofessors.com/graphql'
headers = {
    "Authorization": "Basic dGVzdDp0ZXN0", 
}

# %% [markdown]
# ### Initial request (first 8 professors)

# %%
# data provided for GraphQL
data = {
    "query":"query TeacherSearchPaginationQuery(\n  $count: Int!\n  $cursor: String\n  $query: TeacherSearchQuery!\n) {\n  search: newSearch {\n    ...TeacherSearchPagination_search_1jWD3d\n  }\n}\n\nfragment TeacherSearchPagination_search_1jWD3d on newSearch {\n  teachers(query: $query, first: $count, after: $cursor) {\n    didFallback\n    edges {\n      cursor\n      node {\n        ...TeacherCard_teacher\n        id\n        __typename\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    resultCount\n    filters {\n      field\n      options {\n        value\n        id\n      }\n    }\n  }\n}\n\nfragment TeacherCard_teacher on Teacher {\n  id\n  legacyId\n  avgRating\n  numRatings\n  ...CardFeedback_teacher\n  ...CardSchool_teacher\n  ...CardName_teacher\n  ...TeacherBookmark_teacher\n}\n\nfragment CardFeedback_teacher on Teacher {\n  wouldTakeAgainPercent\n  avgDifficulty\n}\n\nfragment CardSchool_teacher on Teacher {\n  department\n  school {\n    name\n    id\n  }\n}\n\nfragment CardName_teacher on Teacher {\n  firstName\n  lastName\n}\n\nfragment TeacherBookmark_teacher on Teacher {\n  id\n  isSaved\n}\n",
    "variables":{
        "count":4470, # number of professors
        #"cursor":cursor,
        "query":{
            "text":"",
            "schoolID":"U2Nob29sLTEwNzM=",
            "fallback":True,
            "departmentID":None
        }
    }
}

# %%
# response/check status
response = requests.post(url, headers = headers, json=data)
response.raise_for_status()

# %%
# put response into dataframe
cursorDF = pd.DataFrame(response.json()['data']['search']['teachers']['edges'])
cursorDF
# Out:
#                             cursor  \
# 0         YXJyYXljb25uZWN0aW9uOjA=
# 1         YXJyYXljb25uZWN0aW9uOjE=
# 2         YXJyYXljb25uZWN0aW9uOjI=
# 3         YXJyYXljb25uZWN0aW9uOjM=
# 4         YXJyYXljb25uZWN0aW9uOjQ=
# ...                            ...
# 4465  YXJyYXljb25uZWN0aW9uOjQ0NjU=
# 4466  YXJyYXljb25uZWN0aW9uOjQ0NjY=
# 4467  YXJyYXljb25uZWN0aW9uOjQ0Njc=
# 4468  YXJyYXljb25uZWN0aW9uOjQ0Njg=
# 4469  YXJyYXljb25uZWN0aW9uOjQ0Njk=
#
#                                                    node
# 0     {'__typename': 'Teacher', 'avgDifficulty': 2.9...
# 1     {'__typename': 'Teacher', 'avgDifficulty': 2.7...
# 2     {'__typename': 'Teacher', 'avgDifficulty': 3.1...
# 3     {'__typename': 'Teacher', 'avgDifficulty': 2.5...
# 4     {'__typename': 'Teacher', 'avgDifficulty': 3.6...
# ...                                                 ...
# 4465  {'__typename': 'Teacher', 'avgDifficulty': 4.2...
# 4466  {'__typename': 'Teacher', 'avgDifficulty': 3.8...
# 4467  {'__typename': 'Teacher', 'avgDifficulty': 2.6...
# 4468  {'__typename': 'Teacher', 'avgDifficulty': 4.2...
# 4469  {'__typename': 'Teacher', 'avgDifficulty': 4.3...
#
# [4470 rows x 2 columns]

# %%
# initialize dataframe
profs = pd.DataFrame(columns=cursorDF['node'][0].keys())
profs
# Out:
# Empty DataFrame
# Columns: [__typename, avgDifficulty, avgRating, department, firstName, id, isSaved, lastName, legacyId, numRatings, school, wouldTakeAgainPercent]
# Index: []

# %%
# loop to populate profs df
for i in trange(0, len(cursorDF)):
    
    # temporary dictionary
    tempDict = cursorDF['node'][i]
    
    # delete problematic/unnecessary dictionary within dictionary
    del tempDict['school']

    # convert dict to temporary dataframe
    tempDF = pd.DataFrame(tempDict, index=[i])

    # append tempDF to profs df
    profs.loc[len(profs)] = tempDF.iloc[0,:]
# Out:
#   0%|          | 0/4470 [00:00<?, ?it/s]C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
#   1%|          | 42/4470 [00:00<00:10, 419.81it/s]C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
#   2%|▏         | 88/4470 [00:00<00:09, 442.05it/s]C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
#   3%|▎         | 135/4470 [00:00<00:09, 454.43it/s]C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
# ...
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
#  99%|█████████▉| 4426/4470 [00:12<00:00, 268.03it/s]C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# 100%|█████████▉| 4461/4470 [00:12<00:00, 289.87it/s]C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# C:\Users\riley\AppData\Local\Temp\ipykernel_14836\589711243.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   profs.loc[len(profs)] = tempDF.iloc[0,:]
# 100%|██████████| 4470/4470 [00:12<00:00, 360.72it/s]

# %%
# view profs df
profs
# Out:
#      __typename avgDifficulty avgRating            department firstName  \
# 0       Teacher           2.9       3.3             Languages    Robert
# 1       Teacher           2.7       2.6          Anthropology      Aram
# 2       Teacher           3.1       3.2        Social Science   Patrick
# 3       Teacher           2.5       4.5          Anthropology     Henry
# 4       Teacher           3.6       3.8          Anthropology     Peter
# ...         ...           ...       ...                   ...       ...
# 4465    Teacher           4.2       2.5           Mathematics        Fu
# 4466    Teacher           3.8       3.6             Economics     David
# 4467    Teacher           2.6       3.5  Plant & Soil Science    Abhaya
# 4468    Teacher           4.2       2.8               Physics      Dina
# 4469    Teacher           4.3       3.3               Physics       Sam
#
#                         id isSaved       lastName legacyId numRatings  school  \
# 0         VGVhY2hlci05NTY2   False         Borgen     9566         39     NaN
# 1         VGVhY2hlci05NTY4   False       Yengoyan     9568         47     NaN
# 2         VGVhY2hlci05NTcw   False  Carroll-Burke     9570         13     NaN
# 3     VGVhY2hlci0xMzQ4MQ==   False        McHenry    13481        124     NaN
# 4     VGVhY2hlci0yMjIzMA==   False         Rodman    22230         73     NaN
# ...                    ...     ...            ...      ...        ...     ...
# 4465  VGVhY2hlci05NTY1OTg=   False            Liu   956598        127     NaN
# 4466  VGVhY2hlci0xNDczOTYz   False           Lang  1473963        202     NaN
# 4467  VGVhY2hlci0xODM5MDQx   False       Dandekar  1839041          7     NaN
# 4468  VGVhY2hlci0xOTgzMDky   False    Zhabinskaya  1983092         89     NaN
# 4469  VGVhY2hlci0yMzg3Mzg4   False          Blitz  2387388         85     NaN
#
#      wouldTakeAgainPercent
# 0                       -1
# 1                       -1
# 2                       -1
# 3                       -1
# 4                       -1
# ...                    ...
# 4465               56.1404
# 4466                    50
# 4467               66.6667
# 4468               48.3871
# 4469               63.8554
#
# [4470 rows x 12 columns]

# %%
# rearrange columns
profs = profs[['__typename', 'firstName', 'lastName', 'department', 'id', 'legacyId', 'numRatings', 'avgRating', 'avgDifficulty']]
profs
# Out:
#      __typename firstName       lastName            department  \
# 0       Teacher    Robert         Borgen             Languages
# 1       Teacher      Aram       Yengoyan          Anthropology
# 2       Teacher   Patrick  Carroll-Burke        Social Science
# 3       Teacher     Henry        McHenry          Anthropology
# 4       Teacher     Peter         Rodman          Anthropology
# ...         ...       ...            ...                   ...
# 4465    Teacher        Fu            Liu           Mathematics
# 4466    Teacher     David           Lang             Economics
# 4467    Teacher    Abhaya       Dandekar  Plant & Soil Science
# 4468    Teacher      Dina    Zhabinskaya               Physics
# 4469    Teacher       Sam          Blitz               Physics
#
#                         id legacyId numRatings avgRating avgDifficulty
# 0         VGVhY2hlci05NTY2     9566         39       3.3           2.9
# 1         VGVhY2hlci05NTY4     9568         47       2.6           2.7
# 2         VGVhY2hlci05NTcw     9570         13       3.2           3.1
# 3     VGVhY2hlci0xMzQ4MQ==    13481        124       4.5           2.5
# 4     VGVhY2hlci0yMjIzMA==    22230         73       3.8           3.6
# ...                    ...      ...        ...       ...           ...
# 4465  VGVhY2hlci05NTY1OTg=   956598        127       2.5           4.2
# 4466  VGVhY2hlci0xNDczOTYz  1473963        202       3.6           3.8
# 4467  VGVhY2hlci0xODM5MDQx  1839041          7       3.5           2.6
# 4468  VGVhY2hlci0xOTgzMDky  1983092         89       2.8           4.2
# 4469  VGVhY2hlci0yMzg3Mzg4  2387388         85       3.3           4.3
#
# [4470 rows x 9 columns]

# %%
profs.to_csv("profs.csv")
